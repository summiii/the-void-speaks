# %%
from pathlib import Path
import sqlite3

print("CWD:", Path.cwd())
ASSETS = Path("/content/assets")
DB     = Path("/content/music.db") if Path("/content/music.db").exists() else Path("music.db")
print("ASSETS:", ASSETS.resolve(), "exists:", ASSETS.exists())
print("DB:", DB.resolve(), "exists:", DB.exists())

with sqlite3.connect(DB) as con:
    cols = [r[1] for r in con.execute("PRAGMA table_info(tracks);")]
    print("tracks columns:", cols)
    n = con.execute("SELECT COUNT(*) FROM tracks").fetchone()[0] if cols else 0
    print("current track count:", n)
# Out:
# CWD: /content
# ASSETS: /content/assets exists: True
# DB: /content/music.db exists: True
# tracks columns: ['id', 'url', 'local_path', 'title', 'artist', 'album', 'duration', 'bitrate', 'sample_rate', 'channels', 'filesize', 'ext', 'added_at', 'license_id', 'genre']
# current track count: 0

# %%
import requests, time

def discover_first_jobs(query, max_releases=2):
    session = requests.Session()
    adv = "https://archive.org/advancedsearch.php"
    jobs = []
    page=1
    while len(jobs) < max_releases:
        r = session.get(adv, params={
            "q": query, "fl[]":["identifier","title","creator","licenseurl"],
            "output":"json", "rows":50, "page":page
        }, timeout=25)
        r.raise_for_status()
        docs = r.json().get("response",{}).get("docs",[])
        if not docs: break
        for d in docs[:max_releases-len(jobs)]:
            ident  = d.get("identifier")
            title  = d.get("title") or ident
            artist = d.get("creator") or "Unknown"
            licurl = d.get("licenseurl") or "https://archive.org/about/terms.php"
            md = session.get(f"https://archive.org/metadata/{ident}", timeout=25).json()
            files = md.get("files", [])
            urls = [f"https://archive.org/download/{ident}/{f['name']}"
                    for f in files if f.get("name","").lower().endswith((".mp3",".ogg",".m4a",".aac",".wav",".flac"))]
            jobs.append({"ident":ident,"title":title,"artist":artist,"lic":licurl,"urls":urls[:5]})
            time.sleep(0.2)
        page += 1
    return jobs

probe = discover_first_jobs('collection:netlabels AND mediatype:audio AND subject:(ambient)', max_releases=2)
probe
# Out:
# [{'ident': 'gv442',
#   'title': '[GV-442] Astral & Shit - Aqua Marina',
#   'artist': 'Astral & Shit',
#   'lic': 'http://creativecommons.org/licenses/by-nc-nd/3.0/',
#   'urls': ['https://archive.org/download/gv442/Astral & Shit - aqua marina - 01 taiga.mp3',
#    'https://archive.org/download/gv442/Astral & Shit - aqua marina - 01 taiga.ogg',
#    'https://archive.org/download/gv442/Astral & Shit - aqua marina - 02 tail.mp3',
#    'https://archive.org/download/gv442/Astral & Shit - aqua marina - 02 tail.ogg',
#    'https://archive.org/download/gv442/Astral & Shit - aqua marina - 03 jellyfish.mp3']},
#  {'ident': 'polygon009',
#   'title': 'Boy Makes Music - Untitled (Live at The Halifax Experimental Music Festival 9) [polygon009]',
#   'artist': 'Boy Makes Music',
#   'lic': 'http://creativecommons.org/licenses/by-nc-sa/2.0/',
#   'urls': ['https://archive.org/download/polygon009/boy_makes_music-untitled-live_at_hemf-9.mp3']}]

# %%
import sqlite3, pathlib
DB = pathlib.Path("/content/music.db") if pathlib.Path("/content/music.db").exists() else pathlib.Path("music.db")
with sqlite3.connect(DB) as con:
    cols = {r[1] for r in con.execute("PRAGMA table_info(tracks);")}
    if "genre" not in cols:
        con.execute("ALTER TABLE tracks ADD COLUMN genre TEXT;")
        print("✅ added genre")
    else:
        print("✔ genre present")
# Out:
# ✔ genre present

# %%
import requests, os, time, concurrent.futures, sqlite3, re
from urllib.parse import urlparse
from pathlib import Path

ASSETS = Path("/content/assets")
ASSETS.mkdir(parents=True, exist_ok=True)
DB = Path("/content/music.db")

def _safe(name:str)->str:
    return re.sub(r"[^0-9A-Za-z._ -]+","_",name).replace(" ","_")

def read_audio_metadata(path):
    # minimal placeholder (extend later with mutagen)
    return {"title": os.path.basename(path), "artist": "Unknown", "album": "", "duration": 0}

def upsert_track_full(meta, url="", license_code="", license_url="", genre_tag=""):
    with sqlite3.connect(DB) as con:
        c = con.cursor()
        c.execute("""CREATE TABLE IF NOT EXISTS tracks (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            title TEXT, artist TEXT, album TEXT,
            duration REAL, url TEXT, local_path TEXT,
            license_code TEXT, license_url TEXT,
            genre TEXT
        );""")
        c.execute("""INSERT INTO tracks
                     (title, artist, album, duration, url, local_path, license_code, license_url, genre)
                     VALUES (?,?,?,?,?,?,?,?,?)""",
                  (meta["title"], meta["artist"], meta["album"], meta["duration"],
                   url, str(meta.get("path", "")), license_code, license_url, genre_tag))
        con.commit()

def fast_import_from_internet_archive(query, max_items=50, max_workers=8,
                                      max_per_identifier=3, genre_tag="mixed"):
    session = requests.Session()
    search_url = "https://archive.org/advancedsearch.php"
    rows = []
    page = 1
    while len(rows) < max_items:
        r = session.get(search_url, params={
            "q": query,
            "fl[]":["identifier","title","creator","licenseurl"],
            "output":"json", "rows":50, "page":page
        }, timeout=25)
        r.raise_for_status()
        docs = r.json().get("response",{}).get("docs",[])
        if not docs: break
        rows.extend(docs)
        if len(docs) < 50: break
        page += 1
        time.sleep(0.5)
    print(f"Found {len(rows)} results")

    def download_release(doc):
        ident  = doc["identifier"]
        title  = doc.get("title") or ident
        artist = doc.get("creator") or "Unknown"
        licurl = doc.get("licenseurl") or "https://archive.org/about/terms.php"
        md = session.get(f"https://archive.org/metadata/{ident}", timeout=25).json()
        files = md.get("files", [])
        count = 0
        for f in files:
            nm = f.get("name","").lower()
            if nm.endswith((".mp3",".ogg",".m4a",".aac",".wav",".flac")):
                url = f"https://archive.org/download/{ident}/{nm}"
                local = ASSETS / _safe(f"{artist}-{title}-{nm}")
                try:
                    with requests.get(url, stream=True, timeout=30) as rr:
                        rr.raise_for_status()
                        with open(local,"wb") as ff:
                            for chunk in rr.iter_content(1024*64):
                                if chunk: ff.write(chunk)
                    meta = read_audio_metadata(local)
                    meta["path"]=local
                    upsert_track_full(meta,url=url,license_code="CC",license_url=licurl,genre_tag=genre_tag)
                    count += 1
                except Exception as e:
                    print("skip:", nm, "-", e)
                if count>=max_per_identifier: break
        return count

    total=0
    with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as ex:
        for n in ex.map(download_release, rows[:max_items]):
            total+=n
    print("✅ downloaded & indexed", total, "tracks")
    return total

# %%
# --- FIXED, FAST, ROBUST IA IMPORTER (drop-in) ---
# !pip -q install mutagen tqdm

import os, re, time, sqlite3, requests
from pathlib import Path
from urllib.parse import urlparse
from requests.adapters import HTTPAdapter, Retry
from mutagen import File as MF
from tqdm.auto import tqdm

ROOT   = Path("/content")
ASSETS = ROOT / "assets"; ASSETS.mkdir(parents=True, exist_ok=True)
DB     = ROOT / "music.db"

# --- DB schema (safe; includes genre) ---
def ensure_schema():
    with sqlite3.connect(DB) as con:
        con.execute("""
        CREATE TABLE IF NOT EXISTS tracks(
          id INTEGER PRIMARY KEY,
          title TEXT,
          artist TEXT,
          album TEXT,
          duration REAL,
          url TEXT,
          local_path TEXT,
          license_code TEXT,
          license_url TEXT,
          genre TEXT
        )""")
        # ensure genre exists even if table was older
        cols = [r[1] for r in con.execute("PRAGMA table_info(tracks);")]
        if "genre" not in cols:
            con.execute("ALTER TABLE tracks ADD COLUMN genre TEXT;")
    print("✅ schema ok at", DB)

def upsert_track(meta):
    with sqlite3.connect(DB) as con:
        # If this local_path exists, update; else insert.
        row = con.execute("SELECT id FROM tracks WHERE local_path=?", (meta["local_path"],)).fetchone()
        if row:
            con.execute("""UPDATE tracks SET title=?,artist=?,album=?,duration=?,url=?,license_code=?,license_url=?,genre=COALESCE(?,genre)
                           WHERE local_path=?""",
                        (meta["title"], meta["artist"], meta["album"], float(meta["duration"] or 0),
                         meta["url"], meta["license_code"], meta["license_url"], meta["genre"], meta["local_path"]))
        else:
            con.execute("""INSERT INTO tracks(title,artist,album,duration,url,local_path,license_code,license_url,genre)
                           VALUES(?,?,?,?,?,?,?,?,?)""",
                        (meta["title"], meta["artist"], meta["album"], float(meta["duration"] or 0),
                         meta["url"], meta["local_path"], meta["license_code"], meta["license_url"], meta["genre"]))
        con.commit()

def _safe(name:str)->str:
    return re.sub(r"[^0-9A-Za-z._ -]+","_",name).strip().replace(" ","_")

def _ext_from_headers(resp, fallback=".mp3"):
    ct = (resp.headers.get("Content-Type","") or "").lower()
    if "audio/flac" in ct: return ".flac"
    if "audio/wav"  in ct or "x-wav" in ct: return ".wav"
    if "audio/ogg"  in ct: return ".ogg"
    if "audio/mpeg" in ct: return ".mp3"
    if "audio/mp4"  in ct or "aac" in ct or "m4a" in ct: return ".m4a"
    return fallback

def read_audio_metadata(path: Path):
    info = {"title": path.stem, "artist":"Unknown", "album":"Unknown", "duration":0}
    try:
        mfe = MF(path, easy=True)
        if mfe:
            info["title"]  = (mfe.get("title",  [info["title"]]) or [info["title"]])[0]
            info["artist"] = (mfe.get("artist", ["Unknown"])     or ["Unknown"])[0]
            info["album"]  = (mfe.get("album",  ["Unknown"])     or ["Unknown"])[0]
        mf = MF(path)
        if mf and getattr(mf, "info", None):
            info["duration"] = float(getattr(mf.info, "length", 0) or 0)
    except Exception:
        pass
    return info

# Shared requests Session with retries/backoff and UA
def make_session():
    s = requests.Session()
    retries = Retry(
        total=5, backoff_factor=0.6,
        status_forcelist=[429,500,502,503,504],
        allowed_methods=["GET","HEAD"]
    )
    s.mount("https://", HTTPAdapter(max_retries=retries))
    s.headers.update({"User-Agent": "Mozilla/5.0 (TheVoidSpeaks/1.0)"})
    return s

# Keep filename CASE for URL; only use lower() for extension check
def pick_audio_files(files, max_per_identifier=3):
    picked = []
    for f in files:
        name_orig = f.get("name","")         # keep original case
        name_lc   = name_orig.lower()
        if name_lc.endswith((".mp3",".ogg",".m4a",".aac",".wav",".flac")):
            picked.append(name_orig)
        if len(picked) >= max_per_identifier:
            break
    return picked

def fast_import_from_internet_archive(
    query="collection:netlabels AND mediatype:audio",
    max_items=100,
    max_workers=8,
    max_per_identifier=3,
    genre_tag=None,
    polite_delay=0.2
):
    ensure_schema()
    s = make_session()

    # 1) discover identifiers/releases
    jobs = []
    page = 1
    adv = "https://archive.org/advancedsearch.php"
    with tqdm(desc="Discovering", unit="rel") as pbar:
        while len(jobs) < max_items:
            r = s.get(adv, params={
                "q": query,
                "fl[]": ["identifier","title","creator","licenseurl"],
                "output": "json",
                "rows": 50,
                "page": page
            }, timeout=25)
            r.raise_for_status()
            docs = r.json().get("response",{}).get("docs",[])
            if not docs:
                break
            for d in docs:
                if len(jobs) >= max_items: break
                ident  = d.get("identifier")
                title  = d.get("title") or ident
                artist = d.get("creator") or "Unknown"
                licurl = d.get("licenseurl") or "https://archive.org/about/terms.php"
                md = s.get(f"https://archive.org/metadata/{ident}", timeout=25).json()
                files = md.get("files", [])
                picks = pick_audio_files(files, max_per_identifier=max_per_identifier)
                for fname in picks:
                    url = f"https://archive.org/download/{ident}/{fname}"  # ✅ original case
                    jobs.append({
                        "url": url, "title": title, "artist": artist, "album": ident,
                        "license_code": "CC/PD", "license_url": licurl, "genre": genre_tag
                    })
                time.sleep(polite_delay)
            page += 1
            pbar.update(1)

    if not jobs:
        print("No candidates found for query.")
        return 0

    # 2) download sequentially (safer for IA; still fast enough)
    ok = 0; fail = 0
    for j in tqdm(jobs, desc="Downloading", unit="trk"):
        try:
            # decide filename from artist-title + server ext
            ext = os.path.splitext(urlparse(j["url"]).path)[1] or ".mp3"
            fname = _safe(f"{j['artist']}-{j['title']}{ext}")
            out = ASSETS / fname

            if out.exists() and out.stat().st_size > 0:
                meta = read_audio_metadata(out)
                upsert_track({
                    "title":  meta["title"] or j["title"],
                    "artist": meta["artist"] or j["artist"],
                    "album":  meta["album"]  or j["album"],
                    "duration": meta["duration"] or 0,
                    "url": j["url"],
                    "local_path": str(out),
                    "license_code": j["license_code"],
                    "license_url": j["license_url"],
                    "genre": j["genre"]
                })
                ok += 1
                continue

            with s.get(j["url"], stream=True, timeout=45) as r:
                r.raise_for_status()
                # adjust ext if Content-Type says different
                real_ext = _ext_from_headers(r, ext or ".mp3")
                if real_ext and real_ext != ext:
                    ext = real_ext
                    fname = _safe(f"{j['artist']}-{j['title']}{ext}")
                    out = ASSETS / fname
                with open(out, "wb") as f:
                    for chunk in r.iter_content(1024*64):
                        if chunk: f.write(chunk)

            meta = read_audio_metadata(out)
            upsert_track({
                "title":  meta["title"] or j["title"],
                "artist": meta["artist"] or j["artist"],
                "album":  meta["album"]  or j["album"],
                "duration": meta["duration"] or 0,
                "url": j["url"],
                "local_path": str(out),
                "license_code": j["license_code"],
                "license_url": j["license_url"],
                "genre": j["genre"]
            })
            ok += 1
        except Exception as e:
            print("skip:", j["url"], "-", type(e).__name__, e)
            fail += 1

    print(f"Done: {ok} ok, {fail} skipped/failed")
    return ok

# %%
import sqlite3, pathlib
DB = pathlib.Path("/content/music.db")

with sqlite3.connect(DB) as con:
    cur = con.cursor()
    cur.execute("""
    CREATE TABLE IF NOT EXISTS tracks(
      id INTEGER PRIMARY KEY,
      title TEXT,
      artist TEXT,
      album TEXT,
      duration REAL,
      url TEXT,
      local_path TEXT,
      license_code TEXT,
      license_url TEXT,
      genre TEXT
    )
    """)
    cols = [r[1] for r in cur.execute("PRAGMA table_info(tracks);")]

    need = {
        "license_code": "TEXT",
        "license_url": "TEXT",
        "genre": "TEXT",
        "duration": "REAL",
        "local_path": "TEXT"
    }
    for col, sqltype in need.items():
        if col not in cols:
            cur.execute(f"ALTER TABLE tracks ADD COLUMN {col} {sqltype};")

    con.commit()
print("✅ Database schema fixed and ready.")
# Out:
# ✅ Database schema fixed and ready.

# %%
fast_import_from_internet_archive(
    query='collection:netlabels AND mediatype:audio AND subject:(ambient)',
    max_items=20,
    max_per_identifier=2,
    genre_tag="ambient"
)
# Out:
# ✅ schema ok at /content/music.db
# Discovering: 0rel [00:00, ?rel/s]
# Downloading:   0%|          | 0/21 [00:00<?, ?trk/s]
# Done: 21 ok, 0 skipped/failed
# 21

# %%
genres = {
    "ambient": "collection:netlabels AND mediatype:audio AND subject:(ambient OR atmosphere)",
    "lofi": "collection:netlabels AND mediatype:audio AND subject:(lofi OR chillhop OR chill)",
    "electronic": "collection:netlabels AND mediatype:audio AND subject:(electronic OR synth OR downtempo)",
    "rock": "collection:netlabels AND mediatype:audio AND subject:(rock OR alternative OR indie)",
    "jazz": "collection:netlabels AND mediatype:audio AND subject:(jazz OR blues OR swing)",
    "hiphop": "collection:netlabels AND mediatype:audio AND subject:(hiphop OR rap OR beats)",
}

for g, q in genres.items():
    fast_import_from_internet_archive(query=q, max_items=1000, max_per_identifier=3, genre_tag=g)
# Out:
# ✅ schema ok at /content/music.db
# Discovering: 0rel [00:00, ?rel/s]
# Downloading:   0%|          | 0/1000 [00:00<?, ?trk/s]
# Done: 1000 ok, 0 skipped/failed
# ✅ schema ok at /content/music.db
# Discovering: 0rel [00:00, ?rel/s]
# Downloading:   0%|          | 0/1001 [00:00<?, ?trk/s]
# Done: 1001 ok, 0 skipped/failed
# ✅ schema ok at /content/music.db
# Discovering: 0rel [00:00, ?rel/s]
# Downloading:   0%|          | 0/1001 [00:00<?, ?trk/s]
# skip: https://archive.org/download/SomeAncientHoliday/Track 02. Mrs. Danvers - Estuary 883 FDC#3 dedicated.mp3 - HTTPError 404 Client Error: Not Found for url: https://ia600207.us.archive.org/9/items/SomeAncientHoliday/Track%2002.%20Mrs.%20Danvers%20-%20Estuary%20883%20FDC#3%20dedicated.mp3
# Done: 1000 ok, 1 skipped/failed
# ✅ schema ok at /content/music.db
# Discovering: 0rel [00:00, ?rel/s]
# Downloading:   0%|          | 0/1001 [00:00<?, ?trk/s]
# skip: https://archive.org/download/SBTR005BONEYARDSKULLBONG/the Boneyard Sk%C3%BCllbong Rock n Roll Horror Show - 1134.mp3 - HTTPError 404 Client Error: Not Found for url: https://ia803204.us.archive.org/15/items/SBTR005BONEYARDSKULLBONG/the%20Boneyard%20Sk%C3%BCllbong%20Rock%20n%20Roll%20Horror%20Show%20-%201134.mp3
# skip: https://archive.org/download/SBTR005BONEYARDSKULLBONG/the Boneyard Sk%C3%BCllbong Rock n Roll Horror Show - 1134.ogg - HTTPError 404 Client Error: Not Found for url: https://ia903204.us.archive.org/15/items/SBTR005BONEYARDSKULLBONG/the%20Boneyard%20Sk%C3%BCllbong%20Rock%20n%20Roll%20Horror%20Show%20-%201134.ogg
# skip: https://archive.org/download/SBTR005BONEYARDSKULLBONG/the Boneyard Sk%C3%BCllbong Rock n Roll Horror Show - American Horror Story.mp3 - HTTPError 404 Client Error: Not Found for url: https://ia803204.us.archive.org/15/items/SBTR005BONEYARDSKULLBONG/the%20Boneyard%20Sk%C3%BCllbong%20Rock%20n%20Roll%20Horror%20Show%20-%20American%20Horror%20Story.mp3
# Done: 998 ok, 3 skipped/failed
# ✅ schema ok at /content/music.db
# Discovering: 0rel [00:00, ?rel/s]
# Downloading:   0%|          | 0/1001 [00:00<?, ?trk/s]
# Done: 1001 ok, 0 skipped/failed
# ✅ schema ok at /content/music.db
# Discovering: 0rel [00:00, ?rel/s]
# Downloading:   0%|          | 0/1002 [00:00<?, ?trk/s]
# skip: https://archive.org/download/hnr029/01.FuckYourMessiah.flac - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/hnr029/01.FuckYourMessiah.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/hnr029/01.FuckYourMessiah.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/kreislauf140/01_sniff_the_sun_dust.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/kreislauf140/02_rubberneck.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/kreislauf140/03_hot_coppers.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/ende595-pastel-boi-singles-2/01 -  pastel boi - smeared.flac - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/ende595-pastel-boi-singles-2/01 -  pastel boi - smeared.mp3 - OSError [Errno 28] No space left on device: '/content/assets/Unknown-_ENDE595__-pastel_boi_-_Singles_2.mp3'
# skip: https://archive.org/download/ende595-pastel-boi-singles-2/01 -  pastel boi - smeared.wav - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/drcm14/01-Transparente-Vibracion_Solar-Tech_Vibes_Remix.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/drcm14/01-Transparente-Vibracion_Solar-Tech_Vibes_Remix.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/drcm14/02-Loko_Bono-Yakeme_Dub.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/Hiphop-Farwest_-_Hip-Hop-Movement/Der_Patient_-_Back_mit_Battlerap.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/Hiphop-Farwest_-_Hip-Hop-Movement/Der_Patient_-_Ich_bin_bereit.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/Hiphop-Farwest_-_Hip-Hop-Movement/Der_Patient_-_Positiv.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/Mwep004-MoreTripThanHop/01-24-34Point2.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/Mwep004-MoreTripThanHop/01-24-34Point2.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/Mwep004-MoreTripThanHop/01-24-34Point2_64kb.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/POPSAKAL701/1._-_Music/01_Intro_Slavianskij_Duh_Pokoleniia.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/POPSAKAL701/1._-_Music/01_Intro_Slavianskij_Duh_Pokoleniia.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/POPSAKAL701/1._-_Music/02_ACAB.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/POPSAKAL993/01_-_NAPERDEL_V_PROTIVOGAZ_I_NATYANUL_NA_EBALO_LIKVIDATORA.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/POPSAKAL993/01_-_NAPERDEL_V_PROTIVOGAZ_I_NATYANUL_NA_EBALO_LIKVIDATORA.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/POPSAKAL993/02_-_PRINIMAYU_VANNUYU_S_TVOEJ_MAMKOJ_V_BOCHKE_S_RADIATSIONNYIMI_OTHODAMI.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/amp133/1_live @ tape bar (tales for tapes #2).mp3 - HTTPError 404 Client Error: Not Found for url: https://ia601504.us.archive.org/12/items/amp133/1_live%20@%20tape%20bar%20(tales%20for%20tapes%20#2).mp3
# skip: https://archive.org/download/amp133/2_La_wea_al_disco.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/amp133/3_Little_waltz.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/nws322/01 Kofein i CO2.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/nws322/01 Kofein i CO2.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/nws322/02 Enxugando o Gelo.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/SBWS221/01 Adamned Age - Worst Case Szenario.flac - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/SBWS221/01 Adamned Age - Worst Case Szenario.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/SBWS221/01 Adamned Age - Worst Case Szenario.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/Hiphop-Farwest_-_Tricky-M_-_Trickreiches_M/01_-_Tricky-M_-_Ueberfall.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/Hiphop-Farwest_-_Tricky-M_-_Trickreiches_M/02_-_Tricky-M_-_Ebbe_und_Flut.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/Hiphop-Farwest_-_Tricky-M_-_Trickreiches_M/03_-_Tricky-M_-_Chilleffekt.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/POPSAKAL978/1_-_Hellblaze-Kulek_Buhla.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/POPSAKAL978/1_-_Hellblaze-Kulek_Buhla.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/POPSAKAL978/2_-_Hellblaze-POHORONNYIJ_TREK_-MTS_GNIYUSCHIJ_ANUS_COVER-.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/POPSAKAL979/01_-_MC_Vaginator_-_Reznya_v_roddome.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/POPSAKAL979/01_-_MC_Vaginator_-_Reznya_v_roddome.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/POPSAKAL979/02_-_Gegemoniya_SPIDa_-_Pugachiha_-_staraya_mras.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/TPZ35/TPZ35_01_-_frantumHead_-_Panic_by_sickness_-_I.flac - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/TPZ35/TPZ35_01_-_frantumHead_-_Panic_by_sickness_-_I.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/TPZ35/TPZ35_01_-_frantumHead_-_Panic_by_sickness_-_I.wav - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/MALIGNO008/01_-_Elpakito_y_Fonkshow_-_Forceps.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/MALIGNO008/02_-_Elpakito_y_Fonkshow_-_6_Instrumentos.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/MALIGNO008/03_-_Elpakito_y_Fonkshow_-_Black_Lof.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/MNMN571/01. tokuo 1.flac - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/MNMN571/01. tokuo 1.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/MNMN571/01. tokuo 1.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/2018-12-06_Plagiat_RespecteLaPuissancePapale_AudioSources/117607__mefrancis13__fake-vomit-into-toilet.flac - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/2018-12-06_Plagiat_RespecteLaPuissancePapale_AudioSources/117607__mefrancis13__fake-vomit-into-toilet.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/2018-12-06_Plagiat_RespecteLaPuissancePapale_AudioSources/117607__mefrancis13__fake-vomit-into-toilet.wav - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/2019_08_26_Part_2/2019_08_26_11_15_07-167.118bpmStereoRough.flac - OSError [Errno 28] No space left on device: '/content/assets/Lucas_Darklord-2019_08_26_Part_2.flac'
# skip: https://archive.org/download/2019_08_26_Part_2/2019_08_26_11_15_07-167.118bpmStereoRough.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/2019_08_26_Part_2/2019_08_26_11_15_07-167.118bpmStereoRough.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/20250806_20250806_1830/1. Penis.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/20250806_20250806_1830/2. Boy.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/20250806_20250806_1830/3. Milk (Ft. Slimy Joe).mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/The_History_of_Black_Valdo_part_1/bv1.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/The_History_of_Black_Valdo_part_1/bv1.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/Gill_Again/gilligan.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/Gill_Again/gilligan.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/Gill_Again/gilligan_64kb.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/StevenFerris-Knows5mps69/KNOWS5.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/StevenFerris-Knows5mps69/KNOWS5.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/StevenFerris-Knows5mps69/MPS69.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/Franks_and_Beans/franksandbeans.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/Franks_and_Beans/franksandbeans.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/TaoZebong-SupremeCloudTrousers/01 Dreaming Cocoa Flowers.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/TaoZebong-SupremeCloudTrousers/01 Dreaming Cocoa Flowers.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/TaoZebong-SupremeCloudTrousers/02 Fuchsia Lettuce Petals.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/neuroplant13/1Nevermore.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/neuroplant13/2BeatsAreBurning.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/2017-10-17/2017-10-17__dj_matbech.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/onmp053/01Mongrel_Intro.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/onmp053/01Mongrel_Intro.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/onmp053/01Mongrel_Intro_64kb.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/Telfordswarehouselive/01Chicken.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/Telfordswarehouselive/01Chicken.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/Telfordswarehouselive/02HappyMouse.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/SnakesAndStreets/Snakeoil_2a.flac - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/SnakesAndStreets/Snakeoil_2a.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/SnakesAndStreets/Snakeoil_2b.flac - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/DTRASH04-BastardsUnited-ReallyFuckYou/dtrash04_01_all_the_sane.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/DTRASH04-BastardsUnited-ReallyFuckYou/dtrash04_01_all_the_sane.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/DTRASH04-BastardsUnited-ReallyFuckYou/dtrash04_01_all_the_sane_64kb.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/DWK128/Archive_Mind_-_01_-_The_Cycle_of.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/DWK128/Archive_Mind_-_01_-_The_Cycle_of.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/DWK128/Archive_Mind_-_02_-_No_Dialogue.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/DWK213/DJ_Mentos_-_01_-_Invasion.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/DWK213/DJ_Mentos_-_01_-_Invasion.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/DWK213/DJ_Mentos_-_02_-_Oxygen.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/DWK186/Radj_-_01_-_Massaraksh.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/DWK186/Radj_-_01_-_Massaraksh.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/DWK186/Radj_-_02_-_Plankton.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/anakgamessnippet/ANAK - Games (Snippet) - Prod. Lezter x Incendio - Mixed by SunWave.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/CDGelements045/NoiseRhythmTest1.flac - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/CDGelements045/NoiseRhythmTest1.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/CDGelements045/NoiseRhythmTest1.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/maligno-043/1_-_Arhtema-JBMister_-_Deseanos_suerte.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/maligno-043/2_-_Arhtema-JBMister_-_Todo_encaja.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/maligno-043/3_-_Arhtema-JBMister_-_Un_invierno_propio.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/maligno-018/01_-_L.K.A._Producciones_-_Soul_Portrait.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/maligno-018/02_-_L.K.A._Producciones_-_Expresion_Corporal_-con_Squalo-.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/maligno-018/03_-_L.K.A._Producciones_-_Me_Basta_-con_Xheron-.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/VNN-040/01TheVerticalDitchLiftsUpTheStudio.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/VNN-040/01TheVerticalDitchLiftsUpTheStudio.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/VNN-040/01TheVerticalDitchLiftsUpTheStudio_vbr.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/ThaNOdcastv55/ThaNodcastv55.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/ThaNOdcastv55/ThaNodcastv55.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/McFreekyFrogg-TeCagoATiro/McFreekyFrogg-2MyNiggaBizzyBone.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/McFreekyFrogg-TeCagoATiro/McFreekyFrogg-2MyNiggaBizzyBone.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/McFreekyFrogg-TeCagoATiro/McFreekyFrogg-BitchAssWiggaz2013Version.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/Podcast_March2012/201203_HeskinRadiophonic.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/Podcast_March2012/201203_HeskinRadiophonic.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/TON001/01-My_Style.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/TON001/02-Reason_To_Sample.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/TON001/03-Must_Be_Crazy.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/RAWCOFFIN036/Cold - В глупой пустоте (TETSURO Prod.).mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/RAWCOFFIN036/Cold - В глупой пустоте (TETSURO Prod.).ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/refugees-from-beyond-weird-real-freestyle/REfugEEs From Beyond - Weird Real Freestyle - 01 Crunk Fucker Lullaby.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/refugees-from-beyond-weird-real-freestyle/REfugEEs From Beyond - Weird Real Freestyle - 02 Waiting For Nothing.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/refugees-from-beyond-weird-real-freestyle/REfugEEs From Beyond - Weird Real Freestyle - 03 Hauntology Cult.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/frec035/01_planetaldol_remixes_cortex.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/frec035/01_planetaldol_remixes_cortex.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/frec035/02_planetaldol_remixes_atrabilis_sunrise.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/nt018/nt018-1-skoop-acid_jazz.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/nt018/nt018-2-skoop-nova.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/nt018/nt018-3-skoop-okra.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/ntt033/01-binray-amino_domino.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/ntt033/02-binray-tuberthalium.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/ntt033/03-binray-reinvertebrate.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/nws187/01Nabeul.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/nws187/01Nabeul.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/nws187/02AtomOfConsumtion.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/DJ_Farwest-In_The_Hood/DJ_Farwest_-_Chinese_Girl.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/DJ_Farwest-In_The_Hood/DJ_Farwest_-_Dont_Say_Nothing.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/DJ_Farwest-In_The_Hood/DJ_Farwest_-_Fat_Ass.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/piper_ben-Photosynthesis/01CarbonDioxide.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/piper_ben-Photosynthesis/02Osmosis.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/piper_ben-Photosynthesis/03Chlorophyll.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/B.O.K./BOK.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/B.O.K./BOK.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/B.O.K./BOK_64kb.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/nws166/01NimbusTwo.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/nws166/01NimbusTwo.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/nws166/02Blocster.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/renan026/01_intro.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/renan026/01_intro.ogg - OSError [Errno 28] No space left on device: '/content/assets/Patrick_Kokos_feat._Louise_Moon-_RENAN026__Patrick_Kokos_feat._Louise_Moon_-_s_u_p_e_r_2_0_0_8_m_i_x_EP.ogg'
# skip: https://archive.org/download/renan026/02_pekniecienasercu.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/MNMN451/01. Walking.flac - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/MNMN451/01. Walking.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/MNMN451/01. Walking.ogg - OSError [Errno 28] No space left on device: '/content/assets/Tripnectar-Tripnectar_-_Easily__2017___MNMN451_.ogg'
# skip: https://archive.org/download/pi108/pi108_01_Explicite_-_Anonymes.flac - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/pi108/pi108_01_Explicite_-_Anonymes.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/pi108/pi108_01_Explicite_-_Anonymes.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/pi109/pi109_01_Explicite_-_Introspection.flac - OSError [Errno 28] No space left on device: '/content/assets/Explicite-Explicite_-_Alchimie.flac'
# skip: https://archive.org/download/pi109/pi109_01_Explicite_-_Introspection.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/pi109/pi109_01_Explicite_-_Introspection.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/pi115/pi115_01_Explicite_-_Scenario.flac - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/pi115/pi115_01_Explicite_-_Scenario.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/pi115/pi115_01_Explicite_-_Scenario.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/maligno-016/01_-_Squalo_-_Entrada.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/maligno-016/02_-_Squalo_-_Evolucion.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/maligno-016/03_-_Squalo_-_La_Otra_Cara_Del_Hip-Hop_-feat._Oscar-.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/maligno-037/01_-_Xheron_-_Introduccion.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/maligno-037/02_-_Xheron_-_Orgulloso_de_ser_nadie.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/maligno-037/03_-_Xheron_-_Fuera_del_margen_-con_Ana_Garcia-.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/TheEffortlessCrusade/AbusingPeopleInTheNameOfGod.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/TheEffortlessCrusade/AbusingPeopleInTheNameOfGod.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/TheEffortlessCrusade/EveryoneHasFaults.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/onmp208/01_Straight_Component_Alone.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/onmp208/01_Straight_Component_Alone.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/onmp208/02_Straight_Component_Laugh_now_cry_later.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/LLR017/01_Finally.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/LLR017/01_Finally.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/LLR017/01_Finally_64kb.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/evan_morris_wavering_eyes/01-wavering_eyes.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/evan_morris_wavering_eyes/01-wavering_eyes.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/evan_morris_wavering_eyes/02-disassembling.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/go_on_and_get_it/Go_On_And_Get_It.flac - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/go_on_and_get_it/Go_On_And_Get_It.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/go_on_and_get_it/Go_On_And_Get_It.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/ETOnMySpaceshipSINGLE_201305/ET On My Spaceship [SINGLE].flac - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/ETOnMySpaceshipSINGLE_201305/ET On My Spaceship [SINGLE].mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/ETOnMySpaceshipSINGLE_201305/ET On My Spaceship [SINGLE].ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/freihoch2-2008-04-01/freihoch2-2008-04-01-billigundlaut.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/freihoch2-2008-04-01/freihoch2-2008-04-01-billigundlaut.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/freihoch2-2008-04-01/freihoch2-2008-04-01-billigundlaut_64kb.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/indastreetz/01_Fuck_the_RIAA.flac - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/indastreetz/01_Fuck_the_RIAA.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/indastreetz/01_Fuck_the_RIAA.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/TaoZebongDemoTape/Tao Zebong Demo Tape.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/TaoZebongDemoTape/Tao Zebong Demo Tape.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/PrimaDelle9E19/1-soloGrazieATeintro-gelo.flac - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/PrimaDelle9E19/1-soloGrazieATeintro-gelo.mp3 - OSError [Errno 28] No space left on device: '/content/assets/Gelo-Prima_delle_9_e_19.mp3'
# skip: https://archive.org/download/PrimaDelle9E19/1-soloGrazieATeintro-gelo.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/SHM002/LilStewy-LastNightexclusiveSingle.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/SHM002/LilStewy-LastNightexclusiveSingle.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/POPSAKAL592/01_New_Authority_2012_-_2013/01_Novyj_Avtoritet__Single.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/POPSAKAL592/01_New_Authority_2012_-_2013/02_Mama_shaposhnikova_slavy_V_Sperme__Diss_Na_Shaposhnikova.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/POPSAKAL592/01_New_Authority_2012_-_2013/03_Rodilsia_Musor__Smert_Musoram.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/SurplusOf52/01-DeepeningEuropeanCrisis.flac - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/SurplusOf52/01-DeepeningEuropeanCrisis.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/SurplusOf52/01-DeepeningEuropeanCrisis.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/ShaggyHaggard-Anthem_201411/01 - Tro.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/ShaggyHaggard-Anthem_201411/02 - Welcome.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/ShaggyHaggard-Anthem_201411/03 - Anthem.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/kreislauf044/01_kreislauf044.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/kreislauf044/02_kreislauf044.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/kreislauf044/03_kreislauf044.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/TPZ29/TPZ29_01_-_frantumHead_-_vicissitudes_-_vct1.flac - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/TPZ29/TPZ29_01_-_frantumHead_-_vicissitudes_-_vct1.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/TPZ29/TPZ29_01_-_frantumHead_-_vicissitudes_-_vct1.wav - OSError [Errno 28] No space left on device: '/content/assets/frantumHead-frantumHead_-_Vicissitudes__TPZ29_.wav'
# skip: https://archive.org/download/DKR278/01 Track 01.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/DKR278/01 Track 01.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/DKR278/02 Track 02.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/blackguybeats_20130828/dub setp beat no vocal .flac - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/blackguybeats_20130828/dub setp beat no vocal .mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/blackguybeats_20130828/dub setp beat no vocal .ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/BFTG_264/01 1993 Toyota Corolla.flac - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/BFTG_264/01 1993 Toyota Corolla.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/BFTG_264/02 1994 Toyota Corolla.flac - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/FW185/FW185-01_Cherry.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/FW185/FW185-01_Cherry.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/FW185/FW185-02_Cherry_dollheadremix.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/292DIYChurch/292DIYChurch_IRWT_10Shun_WalterGross.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/292DIYChurch/292DIYChurch_IRWT_10Shun_WalterGross.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/sad_martians_from_98K/01 39K.flac - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/sad_martians_from_98K/01 39K.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/sad_martians_from_98K/01 39K.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/Esthing-eternalMidisphere/esthing-EternalMidiSphere.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/Esthing-eternalMidisphere/esthing-EternalMidiSphere.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/MrTalent/MrTalent.flac - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/MrTalent/MrTalent.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/MrTalent/MrTalent.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/SHM002/LilStewy-LastNightexclusiveSingle.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/SHM002/LilStewy-LastNightexclusiveSingle.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/POPSAKAL592/01_New_Authority_2012_-_2013/01_Novyj_Avtoritet__Single.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/POPSAKAL592/01_New_Authority_2012_-_2013/02_Mama_shaposhnikova_slavy_V_Sperme__Diss_Na_Shaposhnikova.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/POPSAKAL592/01_New_Authority_2012_-_2013/03_Rodilsia_Musor__Smert_Musoram.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/SurplusOf52/01-DeepeningEuropeanCrisis.flac - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/SurplusOf52/01-DeepeningEuropeanCrisis.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/SurplusOf52/01-DeepeningEuropeanCrisis.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/ShaggyHaggard-Anthem_201411/01 - Tro.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/ShaggyHaggard-Anthem_201411/02 - Welcome.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/ShaggyHaggard-Anthem_201411/03 - Anthem.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/kreislauf044/01_kreislauf044.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/kreislauf044/02_kreislauf044.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/kreislauf044/03_kreislauf044.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/TPZ29/TPZ29_01_-_frantumHead_-_vicissitudes_-_vct1.flac - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/TPZ29/TPZ29_01_-_frantumHead_-_vicissitudes_-_vct1.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/TPZ29/TPZ29_01_-_frantumHead_-_vicissitudes_-_vct1.wav - OSError [Errno 28] No space left on device: '/content/assets/frantumHead-frantumHead_-_Vicissitudes__TPZ29_.wav'
# skip: https://archive.org/download/DKR278/01 Track 01.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/DKR278/01 Track 01.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/DKR278/02 Track 02.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/RENAN005/01_tlc_in_da_androoz_hauz.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/RENAN005/01_tlc_in_da_androoz_hauz.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/RENAN005/02_i_knew_you_were_dupa_blada.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/BFTG_264/01 1993 Toyota Corolla.flac - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/BFTG_264/01 1993 Toyota Corolla.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/BFTG_264/02 1994 Toyota Corolla.flac - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/Esthing-eternalMidisphere/esthing-EternalMidiSphere.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/Esthing-eternalMidisphere/esthing-EternalMidiSphere.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/top-65/01Trap.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/top-65/02Pillows.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/top-65/03PillowsmagnitRemix.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/cucarabiosa/Cuca Rabiosa/01 Cuca rabiosa.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/cucarabiosa/Cuca Rabiosa/02 con Luis.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/cucarabiosa/Cuca Rabiosa/03 Cucadei.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/BSMX0162/01-TakeTime_12InchMixx.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/BSMX0162/01-TakeTime_12InchMixx.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/BSMX0162/01-TakeTime_12InchMixx_192kb.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/DWK096/Hypoetical_-_01_-_Every_Day_Is_Friday.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/DWK096/Hypoetical_-_01_-_Every_Day_Is_Friday.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/DWK096/Hypoetical_-_02_-_Meditation.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/DWK008/Daakoon_-_01_-_Intro.mp3 - OSError [Errno 28] No space left on device: '/content/assets/Daakoon-Mind_Still_EP.mp3'
# skip: https://archive.org/download/DWK008/Daakoon_-_01_-_Intro.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/DWK008/Daakoon_-_01_-_Intro_vbr.mp3 - OSError [Errno 28] No space left on device: '/content/assets/Daakoon-Mind_Still_EP.mp3'
# skip: https://archive.org/download/DWK059/85_decibel_Monks_-_01_-_Fox_Head_Bar.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/DWK059/85_decibel_Monks_-_01_-_Fox_Head_Bar.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/DWK059/85_decibel_Monks_-_02_-_Cryptic_Text.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/POPSAKAL385/01_-_Evil_Dwarves_-_Pop_Cunt.mp3 - OSError [Errno 28] No space left on device: '/content/assets/VA-Antipop_Split_vol.5__2012_.mp3'
# skip: https://archive.org/download/POPSAKAL385/01_-_Evil_Dwarves_-_Pop_Cunt.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/POPSAKAL385/02_-_Marsh_Goblins_-_Schutzstaffel_Antipop.mp3 - OSError [Errno 28] No space left on device: '/content/assets/VA-Antipop_Split_vol.5__2012_.mp3'
# skip: https://archive.org/download/IBR_535/01. интро.mp3 - OSError [Errno 28] No space left on device: '/content/assets/___-____-_free_style__EP___2018_.mp3'
# skip: https://archive.org/download/IBR_535/01. интро.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/IBR_535/02. много интересных вещей.mp3 - OSError [Errno 28] No space left on device: '/content/assets/___-____-_free_style__EP___2018_.mp3'
# skip: https://archive.org/download/Hiphop-Farwest_-_Double_M_-_RapGeschichte/01_-_Double_M_-_Intro.mp3 - OSError [Errno 28] No space left on device: '/content/assets/Double_M-Hip-Hop_Farwest_-_Double_M_-_RapGeschichte.mp3'
# skip: https://archive.org/download/Hiphop-Farwest_-_Double_M_-_RapGeschichte/02_-_Double_M_-_Movietime.mp3 - OSError [Errno 28] No space left on device: '/content/assets/Double_M-Hip-Hop_Farwest_-_Double_M_-_RapGeschichte.mp3'
# skip: https://archive.org/download/Hiphop-Farwest_-_Double_M_-_RapGeschichte/03_-_Double_M_-_Kaempfernatur.mp3 - OSError [Errno 28] No space left on device: '/content/assets/Double_M-Hip-Hop_Farwest_-_Double_M_-_RapGeschichte.mp3'
# skip: https://archive.org/download/292DIYChurch/292DIYChurch_IRWT_10Shun_WalterGross.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/292DIYChurch/292DIYChurch_IRWT_10Shun_WalterGross.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/DjLeonLamont-FreeGrooves/100bpmMadWarriorTheme-ImaschineMixdown.flac - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/DjLeonLamont-FreeGrooves/100bpmMadWarriorTheme-ImaschineMixdown.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/DjLeonLamont-FreeGrooves/100bpmMadWarriorTheme-ImaschineMixdown.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/CinturonNegro30MinutiDiNoia/01-tuInsultasMiHonorOtraVez..yTeMatare.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/CinturonNegro30MinutiDiNoia/01-tuInsultasMiHonorOtraVez..yTeMatare.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/CinturonNegro30MinutiDiNoia/02-balalaika.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/Mam057-Monastery-TheElection08Epv02008/01EconomicCrisisPart1.flac - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/Mam057-Monastery-TheElection08Epv02008/01EconomicCrisisPart1.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/Mam057-Monastery-TheElection08Epv02008/01EconomicCrisisPart1.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/JimmySpits-LeaPsAndBounds.2008/JimmySpits-LeaPsAndBounds-01-Listen.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/JimmySpits-LeaPsAndBounds.2008/JimmySpits-LeaPsAndBounds-01-Listen.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/JimmySpits-LeaPsAndBounds.2008/JimmySpits-LeaPsAndBounds-01-Listen_64kb.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/IBR_228/01-.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/IBR_228/01-.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/IBR_228/02-.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/FW185/FW185-01_Cherry.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/FW185/FW185-01_Cherry.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/FW185/FW185-02_Cherry_dollheadremix.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/IBR_489/01. Оксимирон в гастроном побежал за говном ( feat. Neoadjuvant Chemotherapy).mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/IBR_489/01. Оксимирон в гастроном побежал за говном ( feat. Neoadjuvant Chemotherapy).ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/IBR_489/02. DICC NA BIZARRE UPROAR (feat. смех НхДхАх).mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/anakgamessnippet/ANAK - Games (Snippet) - Prod. Lezter x Incendio - Mixed by SunWave.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/Warfrap_1988/AudioTrack08.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/Warfrap_1988/AudioTrack08.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/MrTalent/MrTalent.flac - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/MrTalent/MrTalent.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/MrTalent/MrTalent.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/phoke76/phoke76-_-chapter_1-_-01-_-ANIQ_JOINT-_-young_and_beatifull.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/phoke76/phoke76-_-chapter_1-_-02-_-LAMBENT_-_young_and_beatifull.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/phoke76/phoke76-_-chapter_1-_-03-_-COLOSSIUS_-_people_business.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/Gill_Again/gilligan.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/Gill_Again/gilligan.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/Gill_Again/gilligan_64kb.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/Big_Midget/bigmidget.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/Big_Midget/bigmidget.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/Big_Midget/bigmidget_64kb.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/FW095_Heivard/FW095-01_LightRainHeavyRainLightRain.flac - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/FW095_Heivard/FW095-01_LightRainHeavyRainLightRain.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/FW095_Heivard/FW095-01_LightRainHeavyRainLightRain.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/2017-10-17/2017-10-17__dj_matbech.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/AAR00018/BlyadskyDaHuity-GrishaComesToYourHome.HeLikesWithYou.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/AAR00018/BlyadskyDaHuity-GrishaComesToYourHome.HeLikesWithYou.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/FW069_LeKoi/FW069-01_LeKoi_BananaFish.flac - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/FW069_LeKoi/FW069-01_LeKoi_BananaFish.mp3 - OSError [Errno 28] No space left on device: '/content/assets/Le_K_i-Second_Story.mp3'
# skip: https://archive.org/download/FW069_LeKoi/FW069-01_LeKoi_BananaFish.ogg - OSError [Errno 28] No space left on device: '/content/assets/Le_K_i-Second_Story.ogg'
# skip: https://archive.org/download/MIXG009/01_-_Alexander_Chereshnev_-_Weird_Clerkfish_Is_Waking_Up_Hungry_feat_Esdo.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/MIXG009/01_-_Alexander_Chereshnev_-_Weird_Clerkfish_Is_Waking_Up_Hungry_feat_Esdo.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/MIXG009/02_-_VAD_-_Zarya.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/McIpod-EMcIpod/01 Intro To Ipod.flac - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/McIpod-EMcIpod/01 Intro To Ipod.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/McIpod-EMcIpod/02 At Me (2 Dead 2 Care).flac - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/maligno-041/01_-_Flowbredosis_-_Flowbredosis.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/maligno-041/02_-_Flowbredosis_-_Esta_vida_absurda.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/maligno-041/03_-_Flowbredosis_-_Deja_de_piar.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/Hardcore_3/hardcore.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/Hardcore_3/hardcore.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/Hardcore_3/hardcore_64kb.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/MEDUSA_EP/01_Medusa_intro.flac - OSError [Errno 28] No space left on device
# ...
# skip: https://archive.org/download/Pill-Mu.s.gamusicsForStrategyGamesEp/Pill_-_Musga_-_01_-_Intro_64kb.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/MBR002/01-ROSPO_feat_ANTI_L_ONESTO_-_WILLY_VALANGA_-_PLASTE_-_La_mia_bandiera_si_sbriciola.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/MBR002/02-IL_BARO_feat_SCRATCH_MC-Il_solo_sistema_buono.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/MBR002/03-PAC_ONE_-_LOUIS_feat_WAR_BANANA_FOUNDATION_-_The_music_inside.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/TFR1000-VA-SalvationInSoundWaves/01-LowercaseA-RottingAway1kintroelephantknuckleEdit.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/TFR1000-VA-SalvationInSoundWaves/01-LowercaseA-RottingAway1kintroelephantknuckleEdit.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/TFR1000-VA-SalvationInSoundWaves/02-Beastplague-Castration.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/TeethingChrome-GreatestHits-VolumeOne/01 Forehead's Dripping Moisture.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/TeethingChrome-GreatestHits-VolumeOne/01 Forehead's Dripping Moisture.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/TeethingChrome-GreatestHits-VolumeOne/02 Omnichromatic Spectrum.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/RRb001/DGAF Bitch (ft. THE OPER%E2%88%86TOR x IncodN36R0) [prod. by Seanster Monster].flac - HTTPError 404 Client Error: Not Found for url: https://ia803206.us.archive.org/22/items/RRb001/DGAF%20Bitch%20(ft.%20THE%20OPER%E2%88%86TOR%20x%20IncodN36R0)%20%5Bprod.%20by%20Seanster%20Monster%5D.flac
# skip: https://archive.org/download/RRb001/DGAF Bitch (ft. THE OPER%E2%88%86TOR x IncodN36R0) [prod. by Seanster Monster].mp3 - HTTPError 404 Client Error: Not Found for url: https://ia903206.us.archive.org/22/items/RRb001/DGAF%20Bitch%20(ft.%20THE%20OPER%E2%88%86TOR%20x%20IncodN36R0)%20%5Bprod.%20by%20Seanster%20Monster%5D.mp3
# skip: https://archive.org/download/RRb001/DGAF Bitch (ft. THE OPER%E2%88%86TOR x IncodN36R0) [prod. by Seanster Monster].ogg - HTTPError 404 Client Error: Not Found for url: https://ia803206.us.archive.org/22/items/RRb001/DGAF%20Bitch%20(ft.%20THE%20OPER%E2%88%86TOR%20x%20IncodN36R0)%20%5Bprod.%20by%20Seanster%20Monster%5D.ogg
# skip: https://archive.org/download/STAB004/tpr-darling...kiss.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/STAB004/tpr-darling...kiss.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/mhrk392/SPTW - At the Foot of the Ladder - 01 Intro Act.mp3 - OSError [Errno 28] No space left on device: '/content/assets/Unknown-SPTW_-_At_The_Foot_Of_The_Ladder__mhrk392_.mp3'
# skip: https://archive.org/download/mhrk392/SPTW - At the Foot of the Ladder - 02 Yeah Yeah the Birds.mp3 - OSError [Errno 28] No space left on device: '/content/assets/Unknown-SPTW_-_At_The_Foot_Of_The_Ladder__mhrk392_.mp3'
# skip: https://archive.org/download/mhrk392/SPTW - At the Foot of the Ladder - 03 Cecilia-Backwards Into Nothingness.mp3 - OSError [Errno 28] No space left on device: '/content/assets/Unknown-SPTW_-_At_The_Foot_Of_The_Ladder__mhrk392_.mp3'
# skip: https://archive.org/download/neureal002/Lars_Bock-1-Kahprem.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/neureal002/Lars_Bock-1-Kahprem.ogg - OSError [Errno 28] No space left on device: '/content/assets/Unknown-Lars_Bock_-_Ohnrem__neureal002_.ogg'
# skip: https://archive.org/download/neureal002/Lars_Bock-1-Kahprem_64kb.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/ende465-bang-man-mashup-and-munted-vol-1/01 - Bang Man - child.flac - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/ende465-bang-man-mashup-and-munted-vol-1/01 - Bang Man - child.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/ende465-bang-man-mashup-and-munted-vol-1/01 - Bang Man - child.wav - OSError [Errno 28] No space left on device: '/content/assets/Unknown-_ENDE465__Bang_Man_-_Mashup_and_Munted__Volume_1_.wav'
# skip: https://archive.org/download/ende344-tln-patric-catani-digicore-01-27-04/01 - The Last Ninja (feat. Patric Catani) - Part 1.flac - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/ende344-tln-patric-catani-digicore-01-27-04/01 - The Last Ninja (feat. Patric Catani) - Part 1.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/ende344-tln-patric-catani-digicore-01-27-04/01 - The Last Ninja (feat. Patric Catani) - Part 1.wav - OSError [Errno 28] No space left on device: '/content/assets/Unknown-_ENDE344__The_Last_Ninja__feat._Patric_Catani__-_Digicore_Radio_Show__January_27th_2004_.wav'
# skip: https://archive.org/download/BathSalts/Bath Salts.mp3 - OSError [Errno 28] No space left on device: '/content/assets/Meat_Force-Bath_Salts.mp3'
# skip: https://archive.org/download/BathSalts/Bath Salts.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/phlow_mix_004/phlow_mix_004_mo.-das_netaudio_mix_tape_vol_3.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/phlow_mix_004/phlow_mix_004_mo.-das_netaudio_mix_tape_vol_3.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/phlow_mix_004/phlow_mix_004_mo.-das_netaudio_mix_tape_vol_3_64kb.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/pi106/pi106_01_Explicite_-_Explicite_lyrics.flac - OSError [Errno 28] No space left on device: '/content/assets/Explicite-Explicite_-_Expressif.flac'
# skip: https://archive.org/download/pi106/pi106_01_Explicite_-_Explicite_lyrics.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/pi106/pi106_01_Explicite_-_Explicite_lyrics.ogg - OSError [Errno 28] No space left on device: '/content/assets/Explicite-Explicite_-_Expressif.ogg'
# skip: https://archive.org/download/AA005/AA05_01_monsieur_connard-drogue_pour_eskimo.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/AA005/AA05_02_monsieur_connard-y_a_de_la_vie_dans_les_chiottes_publique.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/AA005/AA05_03_monsieur_connard-dereglement_clic-matique.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/music_from_all_around_the_world/01._music_from_all_around_the_world_-_soto_-_orange.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/music_from_all_around_the_world/02._music_from_all_around_the_world_-_the_black_atlantic_-_dandelion.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/music_from_all_around_the_world/03._music_from_all_around_the_world_-_jsvenes_y_sexys_-_el_reloj.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/musik-fuer-schwache-geraete-vol3/00 - TipsyPudel - 90ies Dick n Doof .flac - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/musik-fuer-schwache-geraete-vol3/00 - TipsyPudel - 90ies Dick n Doof .mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/musik-fuer-schwache-geraete-vol3/00 - TipsyPudel - Ambient1 (Hohes Casio Eis).flac - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/nws316/01 Mooving And Grooving.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/nws316/01 Mooving And Grooving.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/nws316/02 Theatrical.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/nws270/01 Super Fight.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/nws270/01 Super Fight.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/nws270/02 Gonna %E2%80%A0.mp3 - HTTPError 404 Client Error: Not Found for url: https://ia601501.us.archive.org/13/items/nws270/02%20Gonna%20%E2%80%A0.mp3
# skip: https://archive.org/download/nqa023/01_alcholic_cindy__new_day_same_shit.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/nqa023/01_alcholic_cindy__new_day_same_shit.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/nqa023/01_alcholic_cindy__new_day_same_shit_64kb.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/nws064/01PoisonStrike.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/nws064/01PoisonStrike.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/nws064/02UziXerox.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/nws400/01 Überfall.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/nws400/01 Überfall.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/nws400/02 cold steel out.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/ntt032/01-kaebin_yield-microglian_activity.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/ntt032/02-kaebin_yield-the_reconfigured_capsid.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/ntt032/03-kaebin_yield-cellular_interior.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/MadMcAbeline-GetSpazzyWithItEp/BackInDizzay.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/MadMcAbeline-GetSpazzyWithItEp/BackInDizzay.ogg - OSError [Errno 28] No space left on device: '/content/assets/Mad_MC_Abeline-Mad_MC_Abeline_-_Get_Spazzy_With_It_EP.ogg'
# skip: https://archive.org/download/MadMcAbeline-GetSpazzyWithItEp/DontMessWithMe.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/The_History_of_Black_Valdo_part_1/bv1.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/The_History_of_Black_Valdo_part_1/bv1.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/Gill_Again/gilligan.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/Gill_Again/gilligan.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/Gill_Again/gilligan_64kb.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/siro258KalciyA.k.a.Ca-ArmeniaSeason/01-KalciyA.k.a.Ca-Intro.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/siro258KalciyA.k.a.Ca-ArmeniaSeason/01-KalciyA.k.a.Ca-Intro.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/siro258KalciyA.k.a.Ca-ArmeniaSeason/02-KalciyA.k.a.Ca-SmotriPoStoronamfeat.D.jaa.s.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/skd854/01. dropping the soap is trve kvlt.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/skd854/01. dropping the soap is trve kvlt.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/skd854/02. I will penetrate ur eye socket.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/MeatForce-RatFries/RatFries.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/MeatForce-RatFries/RatFries.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/Curse_of_the_Fro/basshit2curseofthefro.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/Curse_of_the_Fro/basshit2curseofthefro.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/IBR_196/Мария Сталина - дисс на человеков.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/IBR_196/Мария Сталина - дисс на человеков.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/chokeyouout/chokeyouout.flac - OSError [Errno 28] No space left on device: '/content/assets/Deadman___Digi_Hartatak-Choke_You_Out.flac'
# skip: https://archive.org/download/chokeyouout/chokeyouout.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/chokeyouout/chokeyouout.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/pinkwalrusproductions_gmail/01 Ostacoli sonori-Stratificazioni A.flac - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/pinkwalrusproductions_gmail/01 Ostacoli sonori-Stratificazioni A.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/pinkwalrusproductions_gmail/01 Ostacoli sonori-Stratificazioni A.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/WkBw0037/01Foreplayprelude.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/WkBw0037/01Foreplayprelude.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/WkBw0037/02WakingUpInARoomFilledWithEmptyBottlesnextToAnUnknownPerson.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/ende377-latenights-bump-ep/01 - latenights - Fanfair Lights.flac - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/ende377-latenights-bump-ep/01 - latenights - Fanfair Lights.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/ende377-latenights-bump-ep/01 - latenights - Fanfair Lights.wav - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/f_jumbpod007/jumbpod007_-_moa_pillar_-_jumble_7.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/f_jumbpod007/jumbpod007_-_moa_pillar_-_jumble_7.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/VNN-004/01-TheReturnOfTheButterflyChildren.mp3 - OSError [Errno 28] No space left on device: '/content/assets/Hourglass_Drops-_VNN-004__Return_of_the_Butterfly_Children.mp3'
# skip: https://archive.org/download/VNN-004/01-TheReturnOfTheButterflyChildren.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/VNN-004/01-TheReturnOfTheButterflyChildren_64kb.mp3 - OSError [Errno 28] No space left on device: '/content/assets/Hourglass_Drops-_VNN-004__Return_of_the_Butterfly_Children.mp3'
# skip: https://archive.org/download/The_Song_That_Would_Not_Upload_Life/Life.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/The_Song_That_Would_Not_Upload_Life/Life.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/kreislauf110/01_kreislauf110.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/kreislauf110/02_kreislauf110.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/kreislauf110/03_kreislauf110.mp3 - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/OldSchoolErnyJamSessions/001JoseTheDJ.mp3 - OSError [Errno 28] No space left on device: '/content/assets/Concordant_Opposition_Productions-Old_School_Erny_Jams.mp3'
# skip: https://archive.org/download/OldSchoolErnyJamSessions/001JoseTheDJ.ogg - OSError [Errno 28] No space left on device
# skip: https://archive.org/download/OldSchoolErnyJamSessions/001JoseTheDJ_64kb.mp3 - OSError [Errno 28] No space left on device: '/content/assets/Concordant_Opposition_Productions-Old_School_Erny_Jams.mp3'
# Done: 208 ok, 794 skipped/failed
